# %% [markdown]
# <a href="https://colab.research.google.com/github/ChAbid-773/Basic_Python/blob/main/Basic_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Day 1**

# %% [markdown]
# #*Introduction in Python*

# %%
Start="Hello!"

# %%
Name="Muhammad Abid."

# %%
Father_Name="Mansoor Ahmad."

# %%
City="Bahawalpur."

# %%
Education="The Islamia Universty of Bahawalpur."

# %%
Roll_Number="F24BINFT******"

# %%
CGPA="3.24"

# %%
print(Start,"My name is",Name,"My Father Name is",Father_Name,"I am at studying",Education)
print("My Roll Number is",Roll_Number,"and my Current CGPA is",CGPA,"in 4th Semester.")
print("I am from",City,"Thank You! ")
# Out:
# Hello! My name is Muhammad Abid. My Father Name is Mansoor Ahmad. I am at studying The Islamia Universty of Bahawalpur.
# My Roll Number is F24BINFT****** and my Current CGPA is 3.24 in 4th Semester.
# I am from Bahawalpur. Thank You!

# %% [markdown]
# #*Data Types of Python*

# %%
String="Std","Abid","semester","etc"

# %%
Integar=123,141,11,4,56

# %%
Float=1.1,2.4,14.4

# %%
Boolean=True,False

# %%
print(String)
print(Integar)
print(Float)
print(Boolean)
# Out:
# ('Std', 'Abid', 'semester', 'etc')
# (123, 141, 11, 4, 56)
# (1.1, 2.4, 14.4)
# (True, False)

# %% [markdown]
# #*String Casting Program*

# %% [markdown]
# **1:Farenheit To Celsius**

# %%
Farenheit=float(input("Enter The Temperature of Farenheit:"))
Celsius=(Farenheit-32)*5/9
Celsius=round(Celsius,2)
print("The Temperature of Celsius is:" ,Celsius)
# Out:
# Enter The Temperature of Farenheit:100
# The Temperature of Celsius is: 37.78

# %% [markdown]
# **2:Celsius To Farenheit**

# %%
Celsius=float (input("Enter the Temperature of Celsius:"))
Farenheit=(Celsius*9/5)+32
Farenheit=round(Farenheit,2)
print("The Temperature of Farenheit is:",Farenheit)
# Out:
# Enter the Temperature of Celsius:37.78
# The Temperature of Farenheit is: 100.0

# %% [markdown]
# #**Day 2**

# %% [markdown]
# 3:Check the Integar Value is Odd or Even?

# %%
Number=int(input("Enter the any Integar Number:"))
if(Number%2!=0):
  print(f"Your Number {Number} is Odd")
else:
  print(f"Your Number {Number} is Even")
# Out:
# Enter the any Integar Number:5
# Your Number 5 is Odd

# %% [markdown]
# 4:Check the Leap Year?

# %%
Year=int(input("Enter the Year:"))
if(Year%4==0):
  print(f"{Year} is Leap Year")
else:
  print(f"{Year} is Not Leap Year")
# Out:
# Enter the Year:2024
# 2024 is Leap Year

# %% [markdown]
# 5:Check the Word is Vowels Or Not?

# %%
word=input("Enter the Any Word:")
if(word=="a","e","i","o","u"):
  print(f"{word} is Vowels")
elif(word=="A","E","I","O","U"):
  print(f"{word} is Vowels")
else:
  print(f"{word} is Not Vowels")
# Out:
# Enter the Any Word:aioeu
# aioeu is Vowels

# %% [markdown]
# #*For Loop*

# %% [markdown]
# 1:Print The value of 2 1 4 3 6 5 8 7

# %%
for a in range(1,9,2):
  print(a+1,end=" ")
  print(a,end=" ")
# Out:
# 2 1 4 3 6 5 8 7

# %% [markdown]
# 2:Calculate the Sum of n number

# %%
n=int(input("Enter the Any Number:"))
sum=0
for a in range(1,n+1):
   sum+=a
   print(a,end="+"if a<n else "" )
print(f"={sum}")
# Out:
# Enter the Any Number:8
# 1+2+3+4+5+6+7+8=36

# %% [markdown]
# #**Day 3**

# %% [markdown]
# 3:Repeated Values

# %%
Size=int(input("Enter the Size of Value:"))
Value=input("What do you print the Value:")
sum=""
for a in range(Size):
  sum+=Value+" "
  print(sum)
# Out:
# Enter the Size of Value:7
# What do you print the Value:A
# A
# A A
# A A A
# A A A A
# A A A A A
# A A A A A A
# A A A A A A A

# %% [markdown]
# 4:Table of Multiply

# %%
i=int(input("Enter the Any Number:"))
for a in range(1,11):
  print(f"{i}x{a}={i*a}")
# Out:
# Enter the Any Number:24
# 24x1=24
# 24x2=48
# 24x3=72
# 24x4=96
# 24x5=120
# 24x6=144
# 24x7=168
# 24x8=192
# 24x9=216
# 24x10=240

# %% [markdown]
# 5:Currency Note Counter Program Using a comments

# %%
#User enter the total money amount
amount=int(input("Enter the Total Amount:"))

#Check the total notes of 5000
if(amount>=5000):
  print(int(amount/5000),"Notes of 5000")
  amount=amount%5000  #remaining amount of 5000

#check the total notes of 1000
if(amount>=1000):
  print(int(amount/1000),"Notes of 1000")
  amount=amount%1000  #remaining amount 1000

#check the notes of 500
if(amount>=500):
  print(int(amount/500),"Notes of 500")
  amount=amount%500 #remaining amount 500

#check the notes of 100
if(amount>=100):
  print(int(amount/100),"Notes of 100")
  amount=amount%100 #remaining amount of 100

#check the total notes of 50
if(amount>=50):
  print(int(amount/50),"Notes of 50")
  amount=amount%50 #remaining amount

#check total notes of 20
if(amount>=20):
  print(int(amount/20),"Notes of 20")
  amount=amount%20 #remaining amount of 20

#Check the Coins of below to 20
if(amount>0):
  print(amount, "Rupees in Coins Remaining")
# Out:
# Enter the Total Amount:51899
# 10 Notes of 5000
# 1 Notes of 1000
# 1 Notes of 500
# 3 Notes of 100
# 1 Notes of 50
# 2 Notes of 20
# 9 Rupees in Coins Remaining

# %% [markdown]
# #**Day 4**

# %% [markdown]
# #**Jazz Cash**

# %%
import datetime
Code = input("Enter the Code of JazzCash or Cancel: ").strip().lower()
if Code == "*786#":
            print("""\n    JazzCash
1: Send Money
2: Pay Bills
3: Mobile Load & Bundles
4: ReadyCash
5: Payment
6: My Account
7: Savings & Insurance
8: Rs 100 JazzLoad
9: Buy Now,Pay Later
10: Till Payments
11: Self Service
00: Exit""")

            Service = input("Select a service : ").strip()

            if Service=="00":
                print()

            elif Service == "1":
                    print("""\n  Send Money Service
1: To Mobile Account
2: To CNIC
3: To Bank
4: To Raast/IBAN
00: Exit""")
                    send_money = input("Select money service: ").strip()
                    if send_money == "00":
                        print()

                    elif send_money == "1":
                            print("""\n  Send To Mobile Account
1: To JazzCash
2: To Easypaisa
3: To Upaisa
00: Exit""")
                            mobile_account = input("Select mobile account service: ").strip()
                            if mobile_account == "00":
                                print()

                            elif mobile_account == "1":
                                JazzCash= input("Enter Reciver Jazz Cash Account Number(11 digits): ")
                                amount=float(input("Enter the Amount:"))
                                MPIN=int(input(f"""\nSend RS {amount} to Jazz Cash A/C #{JazzCash} ? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f"Rs {amount} sent successfully to {JazzCash} via JazzCash at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")

                            elif mobile_account == "2":
                                EasyPaisa= input("Enter Reciver Easy Paisa Account Number(11 digits): ")
                                amount=float(input("Enter the Amount:"))
                                MPIN=int(input(f"""\nSend RS {amount} to Easy Paisa A/C #{EasyPaisa} ? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f"Rs {amount} sent successfully to {EasyPaisa} via EasyPaisa at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")

                            elif mobile_account == "3":
                                UPaisa= input("Enter Reciver U Paisa Account Number(11 digits): ")
                                amount=float(input("Enter the Amount:"))
                                MPIN=int(input(f"""\nSend RS {amount} to U Paisa A/C #{UPaisa} ? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f"Rs {amount} sent successfully to {UPaisa} via Upaisa at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")

                            else:
                                print("Invalid option. Try again.")

                    elif send_money == "2":
                        CNIC = input("Enter Reciver CNIC Number(13 digits): ")
                        amount=float(input("Enter the Amount:"))
                        MPIN=int(input(f"""\nSend RS {amount} to CNIC A/C #{CNIC} ? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                        if MPIN==1234:
                          print(f"Rs {amount} sent successfully to {CNIC} via CNIC at the time {datetime.datetime.now()}.")

                        else :
                          print("Invalid MPIN!")

                    elif send_money == "3":
                            print("""\n Bank Account
1: HBL
2: MCB
3: UBL
4: Meezan
5: Allied
00: Back""")
                            Bank_Account=input("Select your Bank Service:").strip()

                            if Bank_Account=="00":
                                print()

                            elif Bank_Account=="1":
                                HBL= input("Enter Reciver 17 digit HBL Account Number: ")
                                amount=float(input("Enter the Amount:"))
                                Mobile_Number= input("Enter Reciver Mobile Number (11 didgits): ")
                                MPIN=int(input(f"""\nSend RS {amount} to HBL A/C #{HBL}? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f"Rs {amount} sent successfully to {HBL} Bank HBL at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")

                            elif Bank_Account=="2":
                                MCB= input("Enter Reciver 17 digit MCB Account Number: ")
                                amount=float(input("Enter the Amount:"))
                                Mobile_Number= input("Enter Reciver Mobile Number (11 didgits): ")
                                MPIN=int(input(f"""\nSend RS {amount} to MCB A/C #{MCB}? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f"Rs {amount} sent successfully to {MCB} Bank MCB at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")

                            elif Bank_Account=="3":
                                UBL= input("Enter Reciver 17 digit UBL Account Number: ")
                                amount=float(input("Enter the Amount:"))
                                Mobile_Number= input("Enter Reciver Mobile Number (11 didgits): ")
                                MPIN=int(input(f"""\nSend RS {amount} to UBL A/C #{UBL}? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f"Rs {amount} sent successfully to {UBL} Bank UBL at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")

                            elif Bank_Account=="4":
                                Meezan= input("Enter Reciver 17 digit Meezan Account Number: ")
                                amount=float(input("Enter the Amount:"))
                                Mobile_Number= input("Enter Reciver Mobile Number (11 didgits): ")
                                MPIN=int(input(f"""\nSend RS {amount} to Meezan A/C #{Meezan}? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f"Rs {amount} sent successfully to {Meezan} Bank Meezan at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")

                            elif Bank_Account=="5":
                                Allied= input("Enter Reciver 17 digit Allied Account Number: ")
                                amount=float(input("Enter the Amount:"))
                                Mobile_Number= input("Enter Reciver Mobile Number (11 didgits): ")
                                MPIN=int(input(f"""\nSend RS {amount} to Allied A/C #{Allied}? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f"Rs {amount} sent successfully to {Allied} Bank Allied at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")

                    elif send_money == "4":
                        RAAST = input("Enter Reciver RASST/IBAN Account Number: ")
                        amount=float(input("Enter the Amount:"))
                        MPIN=int(input(f"""\nSend RS {amount} to RAAST/IBAN A/C #{RAAST} ? FEE: RS 0.00.
Enter Your 4 Digits MPIN:"""))
                        if MPIN==1234:
                          print(f"Rs {amount} sent successfully to {RAAST} via RAAST at the time {datetime.datetime.now()}.")

                        else :
                          print("Invalid MPIN!")

                    else:
                        print("Invalid option. Try again.")


            elif Service == "3":
                    print("""\n  Mobile Load & Bundles
1: Self Load
2: Other Number Load
3: Data Packages / Internet Bundle
00: Exit""")
                    load_Bundles = input("Select the Load & Bundles Service: ").strip()
                    if load_Bundles == "00":
                        print()

                    elif load_Bundles == "1":
                        amount = float(input("Enter load amount (100 to 50000): "))
                        MPIN=int(input(f"Rs {amount} load For self .Enter Your 4 Digits MPIN:"))
                        if MPIN==1234:
                            print(f"Rs {amount} successfully recived the load at the time {datetime.datetime.now()}.")

                        else :
                            print("Invalid MPIN!")

                    elif load_Bundles == "2":
                            print("""\n  Other Load
1: Jazz
2: Zong
3: Telenor
4: Ufone
00: Back""")
                            Other_Load=input("Select the Network :").strip()

                            if Other_Load=="00":
                                print()

                            elif Other_Load=="1":
                                Jazz=input("Enter the Raciver Mobile Number :")
                                amount=float(input("Enter the amount of load :"))
                                MPIN=int(input(f"""\nSend Rs {amount} Jazz load to A/C #{Jazz} ?.Fee RS:0.0.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f" You Rs {amount} Jazz Load sent successfully to {Jazz}  at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")


                            elif Other_Load=="2":
                                Zong=input("Enter the Raciver Mobile Number :")
                                amount=float(input("Enter the amount of load :"))
                                MPIN=int(input(f"""\nSend Rs {amount} Zong load to A/C #{Zong} ?.Fee RS:0.0.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f" You Rs {amount} Zong Load sent successfully to {Zong}  at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")


                            elif Other_Load=="3":
                                Telenor=input("Enter the Raciver Mobile Number :")
                                amount=float(input("Enter the amount of load :"))
                                MPIN=int(input(f"""\nSend Rs {amount} Telenor load to A/C #{Telenor} ?.Fee RS:0.0.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f" You Rs {amount} Telenor Load sent successfully to {Telenor}  at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")


                            elif Other_Load=="4":
                                Ufone=input("Enter the Raciver Mobile Number :")
                                amount=float(input("Enter the amount of load :"))
                                MPIN=int(input(f"""\nSend Rs {amount} Ufone load to A/C #{Ufone} ?.Fee RS:0.0.
Enter Your 4 Digits MPIN:"""))
                                if MPIN==1234:
                                  print(f" You Rs {amount} Ufone Load sent successfully to {Ufone}  at the time {datetime.datetime.now()}.")

                                else :
                                  print("Invalid MPIN!")


                    elif load_Bundles == "3":
                            print("""\n  Packages & Bundles
1: Jazz
2: Zong
3: Telenor
4: Ufone
00: Exit""")
                            Packages=input("Select the Network :").strip()

                            if Packages=="00":
                                print()

                            elif Packages=="1":
                                print("""\n  JAZZ INTERNET PACKAGES
1: Daily Packages
2: 3 Day Packages
3: Weekly Packages
4: Monthly Packages
5: 90 Days Package
00: Exit""")

                                Package_type = input("Select Option: ").strip()
                                # DAILY
                                if Package_type== "1":
                                    print("""\n  Daily Packages )
1: Daily WhatsApp 1GB only Rs 10
2: Daily Super Hours 2GB sirf Rs 35""")
                                    Type=input("Select the Peakage :")
                                    Jazz=input("Enter the Mobile Number :")
                                    MPIN=int(input(f"Enter Your 4 Digits MPIN:"))
                                    if MPIN==1234:
                                      print(f" You successfully Activated the Daily Jazz Bundle in {Jazz}  at the time {datetime.datetime.now()}.")

                                    else :
                                      print("Invalid MPIN!")


                                # 3 DAY
                                elif Package_type == "2":
                                    print("""\n  3 Day Package
1: 3 Day Max Offer  1GB + 1000 Mins + 1000 SMS  Rs 86
2: 3 Day Data 2GB  Rs 100""")
                                    Type=input("Select the Peakage :")
                                    Jazz=input("Enter the Mobile Number :")
                                    MPIN=int(input(f"Enter Your 4 Digits MPIN:"))
                                    if MPIN==1234:
                                      print(f" You successfully Activated the 3 Days Jazz Bundle in {Jazz}  at the time {datetime.datetime.now()}.")

                                    else :
                                      print("Invalid MPIN!")


                                # WEEKLY
                                elif Package_type == "3":
                                    print("""\n  Weekly Packages
1: Weekly Mega 7GB  Rs 210
2: Weekly Mega Plus  24GB  Rs 267""")
                                    Type=input("Select the Peakage :")
                                    Jazz=input("Enter the Mobile Number :")
                                    MPIN=int(input(f"Enter Your 4 Digits MPIN:"))
                                    if MPIN==1234:
                                      print(f" You successfully Activated the Weekly Jazz Bundle in {Jazz}  at the time {datetime.datetime.now()}.")

                                    else :
                                      print("Invalid MPIN!")


                                # MONTHLY
                                elif Package_type == "4":
                                    print("""\n  Monthly Packages
1: Monthly Browser  12GB  Rs 390
2: Monthly Mega  20GB  Rs 600""")
                                    Type=input("Select the Peakage :")
                                    Jazz=input("Enter the Mobile Number :")
                                    MPIN=int(input(f"Enter Your 4 Digits MPIN:"))
                                    if MPIN==1234:
                                      print(f" You successfully Activated the Monthly Jazz Bundle in {Jazz}  at the time {datetime.datetime.now()}.")

                                    else :
                                      print("Invalid MPIN!")


                                # 90 DAYS
                                elif Package_type == "5":
                                    print("""\n 90 Days Package
1: 150GB (50GB per month)  Rs 5650
2: 200GB (Promo)  Rs 6500""")
                                    Type=input("Select the Peakage :")
                                    Jazz=input("Enter the Mobile Number :")
                                    MPIN=int(input(f"Enter Your 4 Digits MPIN:"))
                                    if MPIN==1234:
                                      print(f" You successfully Activated the 90 Days Jazz Bundle in {Jazz}  at the time {datetime.datetime.now()}.")

                                    else :
                                      print("Invalid MPIN!")


                                elif Package_type == "00":
                                    print()


                                else:
                                    print("Invalid option. Try again.")
                            elif Packages == "2":
                                    print("""\n  ZONG INTERNET PACKAGES
1: Daily Packages
2: 3 Day Packages
3: Weekly Packages
4: Monthly Packages
5: 90 Days Package
00: Exit""")

                                    Package_type = input("Select Option: ").strip()

                                    # DAILY
                                    if Package_type == "1":
                                        print("""\n  Daily Packages
1: Daily Basic 100MB  Rs 23
2: Daily Data Max  500MB  Rs 38""")
                                        Type = input("Select the Package : ")
                                        Zong = input("Enter the Mobile Number : ")
                                        MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                        if MPIN == 1234:
                                            print(f"You successfully Activated the Daily Zong Bundle in {Zong} at {datetime.datetime.now()}.")

                                        else:
                                            print("Invalid MPIN!")


                                    # 3 DAY
                                    elif Package_type == "2":
                                        print("""\n  3 Day Package
1: 3 Day Data  2GB Rs 100
2: 3 Day Premium  4GB  Rs 160""")
                                        Type = input("Select the Package : ")
                                        Zong = input("Enter the Mobile Number : ")
                                        MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                        if MPIN == 1234:
                                            print(f"You successfully Activated the 3 Days Zong Bundle in {Zong} at {datetime.datetime.now()}.")

                                        else:
                                            print("Invalid MPIN!")


                                    # WEEKLY
                                    elif Package_type == "3":
                                        print("""\n  Weekly Packages
1: Weekly Data  7GB  Rs 315
2: Weekly Premium  15GB  Rs 420""")
                                        Type = input("Select the Package : ")
                                        Zong = input("Enter the Mobile Number : ")
                                        MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                        if MPIN == 1234:
                                            print(f"You successfully Activated the Weekly Zong Bundle in {Zong} at {datetime.datetime.now()}.")

                                        else:
                                            print("Invalid MPIN!")


                                    # MONTHLY
                                    elif Package_type == "4":
                                        print("""\n  Monthly Packages
1: Monthly Basic  12GB Rs 550
2: Monthly Premium  40GB  Rs 999""")
                                        Type = input("Select the Package : ")
                                        Zong = input("Enter the Mobile Number : ")
                                        MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                        if MPIN == 1234:
                                            print(f"You successfully Activated the Monthly Zong Bundle in {Zong} at {datetime.datetime.now()}.")

                                        else:
                                            print("Invalid MPIN!")


                                    # 90 DAYS
                                    elif Package_type == "5":
                                        print("""\n 90 Days Package
1: 120GB  Rs 4500
2: 200GB  Rs 6500""")
                                        Type = input("Select the Package : ")
                                        Zong = input("Enter the Mobile Number : ")
                                        MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                        if MPIN == 1234:
                                            print(f"You successfully Activated the 90 Days Zong Bundle in {Zong} at {datetime.datetime.now()}.")

                                        else:
                                            print("Invalid MPIN!")


                                    elif Package_type == "00":
                                        print()

                                    else:
                                        print("Invalid option. Try again.")
                            elif Packages == "3":
                                        print("""\n  TELENOR INTERNET PACKAGES
1: Daily Packages
2: 3 Day Packages
3: Weekly Packages
4: Monthly Packages
5: 90 Days Package
00: Exit""")

                                        Package_type = input("Select Option: ").strip()

                                        # DAILY
                                        if Package_type == "1":
                                            print("""\n  Daily Packages
1: Daily Lite  75MB  Rs 15
2: Daily Unlimited (1GB 12AM-8AM)  Rs 25""")
                                            Type = input("Select the Package : ")
                                            Telenor = input("Enter the Mobile Number : ")
                                            MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                            if MPIN == 1234:
                                                print(f"You successfully Activated the Daily Telenor Bundle in {Telenor} at {datetime.datetime.now()}.")

                                            else:
                                                print("Invalid MPIN!")


                                        # 3 DAY
                                        elif Package_type == "2":
                                            print("""\n  3 Day Package
1: 3 Day Data 1.5GB  Rs 80
2: 3 Day Max  3GB  Rs 120""")
                                            Type = input("Select the Package : ")
                                            Telenor = input("Enter the Mobile Number : ")
                                            MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                            if MPIN == 1234:
                                                print(f"You successfully Activated the 3 Days Telenor Bundle in {Telenor} at {datetime.datetime.now()}.")

                                            else:
                                                print("Invalid MPIN!")


                                        # WEEKLY
                                        elif Package_type == "3":
                                            print("""\n  Weekly Packages
1: Weekly Lite  5GB  Rs 240
2: Weekly Unlimited  15GB  Rs 350""")
                                            Type = input("Select the Package : ")
                                            Telenor = input("Enter the Mobile Number : ")
                                            MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                            if MPIN == 1234:
                                                print(f"You successfully Activated the Weekly Telenor Bundle in {Telenor} at {datetime.datetime.now()}.")

                                            else:
                                                print("Invalid MPIN!")


                                        # MONTHLY
                                        elif Package_type == "4":
                                            print("""\n  Monthly Packages
1: Monthly Lite  10GB  Rs 500
2: Monthly Unlimited  30GB  Rs 900""")
                                            Type = input("Select the Package : ")
                                            Telenor = input("Enter the Mobile Number : ")
                                            MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                            if MPIN == 1234:
                                                print(f"You successfully Activated the Monthly Telenor Bundle in {Telenor} at {datetime.datetime.now()}.")

                                            else:
                                                print("Invalid MPIN!")


                                        # 90 DAYS
                                        elif Package_type == "5":
                                            print("""\n  90 Days Package
1: 100GB  Rs 4000
2: 150GB  Rs 5500""")
                                            Type = input("Select the Package : ")
                                            Telenor = input("Enter the Mobile Number : ")
                                            MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                            if MPIN == 1234:
                                                print(f"You successfully Activated the 90 Days Telenor Bundle in {Telenor} at {datetime.datetime.now()}.")

                                            else:
                                                print("Invalid MPIN!")


                                        elif Package_type == "00":
                                            print()

                                        else:
                                            print("Invalid option. Try again.")
                            elif Packages == "4":
                                            print("""\n  UFONE INTERNET PACKAGES
1: Daily Packages
2: 3 Day Packages
3: Weekly Packages
4: Monthly Packages
5: 90 Days Package
00: Exit""")

                                            Package_type = input("Select Option: ").strip()

                                            # DAILY
                                            if Package_type == "1":
                                                print("""\n  Daily Packages
1: Daily Light  500MB  Rs 24
2: Daily Heavy  1GB  Rs 35""")
                                                Type = input("Select the Package : ")
                                                Ufone = input("Enter the Mobile Number : ")
                                                MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                                if MPIN == 1234:
                                                    print(f"You successfully Activated the Daily Ufone Bundle in {Ufone} at {datetime.datetime.now()}.")

                                                else:
                                                    print("Invalid MPIN!")


                                            # 3 DAY
                                            elif Package_type == "2":
                                                print("""\n  3 Day Package
1: 3 Day Plus  2GB  Rs 120
2: 3 Day Max  4GB  Rs 180""")
                                                Type = input("Select the Package : ")
                                                Ufone = input("Enter the Mobile Number : ")
                                                MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                                if MPIN == 1234:
                                                    print(f"You successfully Activated the 3 Days Ufone Bundle in {Ufone} at {datetime.datetime.now()}.")

                                                else:
                                                    print("Invalid MPIN!")


                                            # WEEKLY
                                            elif Package_type == "3":
                                                print("""\n  Weekly Packages
1: Weekly Internet Plus  6GB  Rs 299
2: Weekly Super  12GB  Rs 399""")
                                                Type = input("Select the Package : ")
                                                Ufone = input("Enter the Mobile Number : ")
                                                MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                                if MPIN == 1234:
                                                    print(f"You successfully Activated the Weekly Ufone Bundle in {Ufone} at {datetime.datetime.now()}.")

                                                else:
                                                    print("Invalid MPIN!")


                                            # MONTHLY
                                            elif Package_type == "4":
                                                print("""\n  Monthly Packages
1: Monthly Light  10GB  Rs 699
2: Monthly Heavy  25GB  Rs 1199""")
                                                Type = input("Select the Package : ")
                                                Ufone = input("Enter the Mobile Number : ")
                                                MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                                if MPIN == 1234:
                                                    print(f"You successfully Activated the Monthly Ufone Bundle in {Ufone} at {datetime.datetime.now()}.")

                                                else:
                                                    print("Invalid MPIN!")


                                            # 90 DAYS
                                            elif Package_type == "5":
                                                print("""\n  90 Days Package
1: 100GB  Rs 4500
2: 150GB  Rs 6000""")
                                                Type = input("Select the Package : ")
                                                if Type == "1" or "2":
                                                    Ufone = input("Enter the Mobile Number : ")
                                                    MPIN = int(input("Enter Your 4 Digits MPIN: "))

                                                    if MPIN == 1234:
                                                        print(f"You successfully Activated the 90 Days Ufone Bundle in {Ufone} at {datetime.datetime.now()}.")

                                                    else:
                                                        print("Invalid MPIN!")

                                                else:
                                                    print("Invalid Type")


                                            elif Package_type == "00":
                                                print()

                                            else:
                                                print("Invalid option. Try again.")
                    else:
                        print("Invalid option. Try again.")

            elif Service == "00":
                print("Exiting JazzCash. Thank you!")
                exit()  # Exits the whole program

            else:
                print("Invalid Service Option. Try Again!")
elif Code=="cancel":
    print()
else:
    print("Invalid JazzCash code. Please enter *786# to continue.")
# Out:
# Enter the Code of JazzCash or Cancel: *786#
#
#     JazzCash
# 1: Send Money
# 2: Pay Bills
# 3: Mobile Load & Bundles
# 4: ReadyCash
# 5: Payment
# 6: My Account
# 7: Savings & Insurance
# 8: Rs 100 JazzLoad
# 9: Buy Now,Pay Later
# 10: Till Payments
# 11: Self Service
# 00: Exit
# Select a service : 3
#
#   Mobile Load & Bundles
# 1: Self Load
# 2: Other Number Load
# 3: Data Packages / Internet Bundle
# 00: Exit
# Select the Load & Bundles Service: 3
#
#   Packages & Bundles
# 1: Jazz
# 2: Zong
# 3: Telenor
# 4: Ufone
# 00: Exit
# Select the Network :2
#
#   ZONG INTERNET PACKAGES
# 1: Daily Packages
# 2: 3 Day Packages
# 3: Weekly Packages
# 4: Monthly Packages
# 5: 90 Days Package
# 00: Exit
# Select Option: 4
#
#   Monthly Packages
# 1: Monthly Basic  12GB Rs 550
# 2: Monthly Premium  40GB  Rs 999
# Select the Package : 2
# Enter the Mobile Number : 03100000000
# Enter Your 4 Digits MPIN: 1234
# ...

# %% [markdown]
# #**Day 4**

# %% [markdown]
# #*While Loop*

# %% [markdown]
# **1:Table of Multiply**

# %%
i=1
while i<=10:
  if i*2==20:
    print("2 * 10 = 20")
    break
  print(f"2 *  {i} = {i*2}")
  i=i+1
# Out:
# 2 *  1 = 2
# 2 *  2 = 4
# 2 *  3 = 6
# 2 *  4 = 8
# 2 *  5 = 10
# 2 *  6 = 12
# 2 *  7 = 14
# 2 *  8 = 16
# 2 *  9 = 18
# 2 * 10 = 20

# %% [markdown]
# **2: Create a Diamond**

# %%
for i in range(5,0,-1):
  spaces=6*(5-i)
  print("*  "* i+" " * spaces + "*  " *i)
for i in range(1,6,1):
  spaces=6*(5-i)
  print("*  "* i+" " * spaces + "*  " *i)
# Out:
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *        *  *  *  *
# *  *  *              *  *  *
# *  *                    *  *
# *                          *
# *                          *
# *  *                    *  *
# *  *  *              *  *  *
# *  *  *  *        *  *  *  *
# *  *  *  *  *  *  *  *  *  *

# %% [markdown]
# **3:Create a Diamond**

# %%
for i in range(1, 8  ,1):
    print(("A   " * i).center(8 * 4 - 1))

for i in range(8, 0, -1):
    print(("A   " * i).center(8 * 4 - 1))
# Out:
#               A
#             A   A
#           A   A   A
#         A   A   A   A
#       A   A   A   A   A
#     A   A   A   A   A   A
#   A   A   A   A   A   A   A
# A   A   A   A   A   A   A   A
#   A   A   A   A   A   A   A
#     A   A   A   A   A   A
#       A   A   A   A   A
#         A   A   A   A
#           A   A   A
#             A   A
#               A

# %% [markdown]
# **Check the Time**

# %%
import time
time.asctime()
# Out:
# 'Wed May 13 08:49:54 2026'

# %% [markdown]
# **Use the Set method and print the data types**

# %%
set={"Q","A",23.2,22}
set.add(33)
set
# Out:
# {22, 23.2, 33, 'A', 'Q'}

# %% [markdown]
# **Print the letter in cross Shap**

# %%
a=5
for i in range(a):
    if i == 0:
        print("A" + " " * 16 + "F")
    elif i == 1:
        print(" " * 4 + "B" + " " * 7 + "D")
    elif i == 2:
        print(" " * 8 + "C")
    elif i == 3:
        print(" " * 4 + "B" + " " * 7 + "D")
    elif i == 4:
        print("A" + " " * 16 + "F")
# Out:
# A                F
#     B       D
#         C
#     B       D
# A                F

# %% [markdown]
# **Check the largest number with use the For Loop**

# %%
b=0
a=[1,2,4,3]
for i in a:
  if i>b:
    b=i
print(b)
# Out:
# 4
